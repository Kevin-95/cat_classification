# %%
# 查看当前挂载的数据集目录
# !ls /home/aistudio/data/
# Out:
# data7983

# %%
# 查看个人持久化工作区文件
# !ls /home/aistudio/work/
# Out:
# pretrained

# %% [markdown]
# !unzip data/data7983/cat_12.zip

# %%
# !wget http://paddle-imagenet-models-name.bj.bcebos.com/ResNet50_vd_pretrained.tar
# Out:
# --2019-06-17 11:42:16--  http://paddle-imagenet-models-name.bj.bcebos.com/ResNet101_pretrained.tar
# Resolving paddle-imagenet-models-name.bj.bcebos.com (paddle-imagenet-models-name.bj.bcebos.com)... 220.181.33.48, 220.181.33.43, 220.181.33.44, ...
# Connecting to paddle-imagenet-models-name.bj.bcebos.com (paddle-imagenet-models-name.bj.bcebos.com)|220.181.33.48|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 179148800 (171M) [application/x-tar]
# Saving to: ‘ResNet101_pretrained.tar’
#
# ResNet101_pretraine 100%[===================>] 170.85M  20.4MB/s    in 6.0s
#
# 2019-06-17 11:42:23 (28.7 MB/s) - ‘ResNet101_pretrained.tar’ saved [179148800/179148800]

# %%
# !tar -xvf ResNet50_vd_pretrained.tar -C work/pretrained
# Out:
# ResNet101_pretrained/
# ResNet101_pretrained/res4b19_branch2b_weights
# ResNet101_pretrained/bn5a_branch2b_scale
# ResNet101_pretrained/bn4b8_branch2c_mean
# ResNet101_pretrained/bn4b16_branch2b_mean
# ResNet101_pretrained/bn4b1_branch2b_scale
# ResNet101_pretrained/bn3b_branch2c_offset
# ResNet101_pretrained/bn4b2_branch2b_variance
# ResNet101_pretrained/res4b1_branch2c_weights
# ResNet101_pretrained/bn4b1_branch2c_variance
# ResNet101_pretrained/bn4b22_branch2c_variance
# ResNet101_pretrained/bn5c_branch2b_variance
# ResNet101_pretrained/bn3a_branch2a_variance
# ResNet101_pretrained/res4b5_branch2b_weights
# ResNet101_pretrained/bn4b5_branch2b_scale
# ResNet101_pretrained/bn4b2_branch2b_scale
# ResNet101_pretrained/bn3a_branch1_offset
# ResNet101_pretrained/bn4b8_branch2b_offset
# ResNet101_pretrained/bn5a_branch2c_variance
# ResNet101_pretrained/bn4b18_branch2a_offset
# ResNet101_pretrained/bn4b20_branch2b_offset
# ResNet101_pretrained/bn3c_branch2a_variance
# ResNet101_pretrained/bn3b_branch2b_mean
# ResNet101_pretrained/res4b9_branch2b_weights
# ResNet101_pretrained/res2a_branch2b_weights
# ResNet101_pretrained/bn4b20_branch2b_scale
# ResNet101_pretrained/bn3b_branch2a_offset
# ResNet101_pretrained/bn4b4_branch2b_scale
# ResNet101_pretrained/bn4b15_branch2a_scale
# ResNet101_pretrained/bn3a_branch2a_mean
# ResNet101_pretrained/bn3c_branch2c_offset
# ResNet101_pretrained/bn4b18_branch2c_mean
# ResNet101_pretrained/bn3b_branch2c_variance
# ResNet101_pretrained/bn4b4_branch2b_variance
# ResNet101_pretrained/bn4b20_branch2c_offset
# ResNet101_pretrained/bn4b2_branch2c_offset
# ResNet101_pretrained/bn4b11_branch2c_mean
# ResNet101_pretrained/bn4b14_branch2b_scale
# ResNet101_pretrained/bn4b17_branch2a_offset
# ResNet101_pretrained/bn5c_branch2a_offset
# ResNet101_pretrained/bn3d_branch2b_mean
# ResNet101_pretrained/bn4a_branch2b_mean
# ResNet101_pretrained/bn4b20_branch2b_mean
# ResNet101_pretrained/bn4b15_branch2c_mean
# ResNet101_pretrained/bn4b9_branch2c_variance
# ResNet101_pretrained/bn4b3_branch2a_variance
# ResNet101_pretrained/bn4b16_branch2a_scale
# ResNet101_pretrained/res4b2_branch2c_weights
# ResNet101_pretrained/bn5a_branch2a_variance
# ResNet101_pretrained/res4b11_branch2c_weights
# ResNet101_pretrained/bn5a_branch2a_mean
# ResNet101_pretrained/bn4b22_branch2a_offset
# ResNet101_pretrained/bn3b_branch2a_scale
# ResNet101_pretrained/bn5a_branch1_mean
# ResNet101_pretrained/bn4b14_branch2b_variance
# ResNet101_pretrained/bn4b15_branch2c_scale
# ResNet101_pretrained/res4b8_branch2c_weights
# ResNet101_pretrained/bn4b4_branch2c_mean
# ResNet101_pretrained/bn5a_branch2c_offset
# ResNet101_pretrained/bn4b12_branch2a_mean
# ResNet101_pretrained/res4b21_branch2c_weights
# ResNet101_pretrained/bn4b8_branch2c_scale
# ResNet101_pretrained/bn4b6_branch2b_variance
# ResNet101_pretrained/bn4b22_branch2c_offset
# ResNet101_pretrained/bn4b3_branch2b_variance
# ResNet101_pretrained/bn2a_branch2b_variance
# ResNet101_pretrained/bn4b12_branch2b_scale
# ResNet101_pretrained/res4b15_branch2b_weights
# ResNet101_pretrained/bn2b_branch2b_variance
# ResNet101_pretrained/bn4b14_branch2a_offset
# ResNet101_pretrained/bn3b_branch2b_variance
# ResNet101_pretrained/bn4b3_branch2b_offset
# ResNet101_pretrained/bn4b11_branch2a_variance
# ResNet101_pretrained/bn4b13_branch2a_scale
# ResNet101_pretrained/bn5c_branch2b_offset
# ResNet101_pretrained/bn4b6_branch2a_variance
# ResNet101_pretrained/bn_conv1_offset
# ResNet101_pretrained/bn4b6_branch2b_mean
# ResNet101_pretrained/bn4b21_branch2b_scale
# ResNet101_pretrained/res3d_branch2b_weights
# ResNet101_pretrained/bn4b7_branch2c_scale
# ResNet101_pretrained/bn4b1_branch2a_mean
# ResNet101_pretrained/bn4a_branch2b_variance
# ResNet101_pretrained/bn4b22_branch2b_scale
# ResNet101_pretrained/res5a_branch2c_weights
# ResNet101_pretrained/bn4b20_branch2a_scale
# ResNet101_pretrained/bn4b6_branch2c_mean
# ResNet101_pretrained/bn4b8_branch2a_scale
# ResNet101_pretrained/bn4b22_branch2b_variance
# ResNet101_pretrained/bn2a_branch2a_scale
# ResNet101_pretrained/bn4a_branch1_offset
# ResNet101_pretrained/bn4b8_branch2a_offset
# ResNet101_pretrained/res3b_branch2a_weights
# ResNet101_pretrained/bn4a_branch2c_variance
# ResNet101_pretrained/res4b7_branch2a_weights
# ResNet101_pretrained/bn4b22_branch2c_mean
# ResNet101_pretrained/bn4b12_branch2c_offset
# ResNet101_pretrained/bn4b18_branch2a_scale
# ResNet101_pretrained/bn4b11_branch2a_scale
# ResNet101_pretrained/bn4b11_branch2c_variance
# ResNet101_pretrained/bn5a_branch2b_mean
# ResNet101_pretrained/bn4b3_branch2a_offset
# ResNet101_pretrained/bn4b21_branch2a_variance
# ResNet101_pretrained/bn3c_branch2b_mean
# ResNet101_pretrained/bn4b16_branch2c_variance
# ResNet101_pretrained/bn_conv1_scale
# ResNet101_pretrained/bn4b22_branch2c_scale
# ResNet101_pretrained/bn4b10_branch2b_variance
# ResNet101_pretrained/bn4b20_branch2a_mean
# ResNet101_pretrained/bn4b6_branch2b_offset
# ResNet101_pretrained/bn3d_branch2c_variance
# ResNet101_pretrained/bn4b22_branch2b_mean
# ResNet101_pretrained/fc_0.b_0
# ResNet101_pretrained/res3b_branch2b_weights
# ResNet101_pretrained/bn4b11_branch2c_scale
# ResNet101_pretrained/res4b18_branch2b_weights
# ResNet101_pretrained/res3b_branch2c_weights
# ResNet101_pretrained/bn3a_branch2b_mean
# ResNet101_pretrained/bn4b21_branch2c_mean
# ResNet101_pretrained/bn5b_branch2b_variance
# ResNet101_pretrained/bn2c_branch2a_mean
# ResNet101_pretrained/bn4b1_branch2c_mean
# ResNet101_pretrained/bn4b12_branch2c_variance
# ResNet101_pretrained/bn4b11_branch2b_variance
# ResNet101_pretrained/bn4b15_branch2b_variance
# ResNet101_pretrained/bn4b2_branch2a_scale
# ResNet101_pretrained/res4b13_branch2c_weights
# ResNet101_pretrained/bn4a_branch2a_mean
# ResNet101_pretrained/bn4a_branch2b_scale
# ResNet101_pretrained/bn2a_branch1_mean
# ResNet101_pretrained/bn4b10_branch2a_variance
# ResNet101_pretrained/bn4b14_branch2c_offset
# ResNet101_pretrained/bn4b4_branch2a_scale
# ResNet101_pretrained/bn4b5_branch2a_offset
# ResNet101_pretrained/bn4b9_branch2c_scale
# ResNet101_pretrained/res4b7_branch2b_weights
# ResNet101_pretrained/bn_conv1_variance
# ResNet101_pretrained/bn5c_branch2c_scale
# ResNet101_pretrained/bn3c_branch2a_mean
# ResNet101_pretrained/bn4b16_branch2b_offset
# ResNet101_pretrained/bn2a_branch1_offset
# ResNet101_pretrained/res4a_branch2c_weights
# ResNet101_pretrained/bn2c_branch2c_scale
# ResNet101_pretrained/bn4b17_branch2b_scale
# ResNet101_pretrained/res4b6_branch2a_weights
# ResNet101_pretrained/bn5b_branch2c_offset
# ResNet101_pretrained/bn4b18_branch2a_mean
# ResNet101_pretrained/bn2c_branch2b_offset
# ResNet101_pretrained/bn4a_branch2c_mean
# ResNet101_pretrained/bn4b6_branch2a_mean
# ResNet101_pretrained/bn2a_branch2a_mean
# ResNet101_pretrained/bn2b_branch2a_offset
# ResNet101_pretrained/bn5b_branch2a_offset
# ResNet101_pretrained/bn3d_branch2b_scale
# ResNet101_pretrained/bn4b16_branch2b_variance
# ResNet101_pretrained/bn4b18_branch2a_variance
# ResNet101_pretrained/bn4b3_branch2b_mean
# ResNet101_pretrained/res4b5_branch2a_weights
# ResNet101_pretrained/bn4b11_branch2c_offset
# ResNet101_pretrained/res4b2_branch2b_weights
# ResNet101_pretrained/res5b_branch2c_weights
# ResNet101_pretrained/bn4b8_branch2b_mean
# ResNet101_pretrained/res2c_branch2a_weights
# ResNet101_pretrained/res4b19_branch2c_weights
# ResNet101_pretrained/bn3d_branch2a_scale
# ResNet101_pretrained/bn4b18_branch2b_mean
# ResNet101_pretrained/bn2a_branch2b_scale
# ResNet101_pretrained/bn3a_branch2c_scale
# ResNet101_pretrained/res4b7_branch2c_weights
# ResNet101_pretrained/bn4b10_branch2a_mean
# ResNet101_pretrained/res2a_branch2a_weights
# ResNet101_pretrained/bn3b_branch2a_variance
# ResNet101_pretrained/bn4b9_branch2a_mean
# ResNet101_pretrained/bn4b2_branch2c_scale
# ResNet101_pretrained/bn4b9_branch2c_offset
# ResNet101_pretrained/res3c_branch2c_weights
# ResNet101_pretrained/bn4b10_branch2c_offset
# ResNet101_pretrained/bn4b2_branch2a_mean
# ResNet101_pretrained/bn4b15_branch2a_offset
# ResNet101_pretrained/bn4b21_branch2a_scale
# ResNet101_pretrained/bn4b18_branch2b_variance
# ResNet101_pretrained/bn3a_branch2c_variance
# ResNet101_pretrained/bn4a_branch2c_scale
# ResNet101_pretrained/bn3a_branch1_mean
# ResNet101_pretrained/bn4b6_branch2c_offset
# ResNet101_pretrained/bn4b4_branch2a_variance
# ResNet101_pretrained/bn3a_branch2b_variance
# ResNet101_pretrained/bn4b4_branch2b_mean
# ResNet101_pretrained/bn5b_branch2c_scale
# ResNet101_pretrained/res4b20_branch2a_weights
# ResNet101_pretrained/bn4b7_branch2a_scale
# ResNet101_pretrained/res3a_branch2c_weights
# ResNet101_pretrained/bn4b14_branch2b_offset
# ResNet101_pretrained/bn4b16_branch2c_scale
# ResNet101_pretrained/bn4b7_branch2c_variance
# ResNet101_pretrained/bn4b2_branch2c_variance
# ResNet101_pretrained/bn4b7_branch2a_mean
# ResNet101_pretrained/bn4b5_branch2a_mean
# ResNet101_pretrained/bn4b14_branch2c_variance
# ResNet101_pretrained/bn4b15_branch2a_mean
# ResNet101_pretrained/res5a_branch2a_weights
# ResNet101_pretrained/res4b18_branch2c_weights
# ResNet101_pretrained/bn4b8_branch2c_offset
# ResNet101_pretrained/bn4b18_branch2b_offset
# ResNet101_pretrained/bn4b21_branch2a_mean
# ResNet101_pretrained/res4b6_branch2b_weights
# ResNet101_pretrained/bn3b_branch2c_scale
# ResNet101_pretrained/bn4b20_branch2c_variance
# ResNet101_pretrained/bn3c_branch2b_variance
# ResNet101_pretrained/bn5a_branch1_variance
# ResNet101_pretrained/bn2c_branch2c_mean
# ResNet101_pretrained/bn2a_branch2c_mean
# ResNet101_pretrained/res4b15_branch2a_weights
# ResNet101_pretrained/res4b2_branch2a_weights
# ResNet101_pretrained/bn4b15_branch2b_mean
# ResNet101_pretrained/res4b15_branch2c_weights
# ResNet101_pretrained/bn5a_branch2a_offset
# ResNet101_pretrained/bn3d_branch2c_scale
# ResNet101_pretrained/res2b_branch2b_weights
# ResNet101_pretrained/res4b1_branch2b_weights
# ResNet101_pretrained/bn4b10_branch2b_mean
# ResNet101_pretrained/bn4b13_branch2c_scale
# ResNet101_pretrained/bn2b_branch2b_mean
# ResNet101_pretrained/bn4b1_branch2b_offset
# ResNet101_pretrained/bn4b20_branch2a_offset
# ResNet101_pretrained/bn4b16_branch2c_mean
# ResNet101_pretrained/bn4b13_branch2b_mean
# ResNet101_pretrained/bn2c_branch2b_mean
# ResNet101_pretrained/bn2c_branch2a_scale
# ResNet101_pretrained/bn4a_branch2a_offset
# ResNet101_pretrained/bn4b17_branch2a_variance
# ResNet101_pretrained/bn3d_branch2b_variance
# ResNet101_pretrained/bn4b22_branch2a_scale
# ResNet101_pretrained/bn4b12_branch2c_mean
# ResNet101_pretrained/bn4b7_branch2b_variance
# ResNet101_pretrained/bn4b8_branch2b_scale
# ResNet101_pretrained/res3d_branch2c_weights
# ResNet101_pretrained/bn4b5_branch2c_mean
# ResNet101_pretrained/bn4b4_branch2c_offset
# ResNet101_pretrained/bn3a_branch2c_offset
# ResNet101_pretrained/bn3c_branch2c_mean
# ResNet101_pretrained/bn4a_branch2a_scale
# ResNet101_pretrained/bn3d_branch2a_variance
# ResNet101_pretrained/bn4b14_branch2b_mean
# ResNet101_pretrained/bn4b9_branch2a_offset
# ResNet101_pretrained/res4b13_branch2b_weights
# ResNet101_pretrained/bn4b22_branch2a_variance
# ResNet101_pretrained/bn4b19_branch2b_variance
# ResNet101_pretrained/res4b14_branch2b_weights
# ResNet101_pretrained/bn5b_branch2b_mean
# ResNet101_pretrained/res2b_branch2a_weights
# ResNet101_pretrained/res2a_branch2c_weights
# ResNet101_pretrained/res4b3_branch2b_weights
# ResNet101_pretrained/bn4b14_branch2a_variance
# ResNet101_pretrained/res4b17_branch2c_weights
# ResNet101_pretrained/res4b1_branch2a_weights
# ResNet101_pretrained/res4b11_branch2a_weights
# ResNet101_pretrained/bn4b15_branch2c_offset
# ResNet101_pretrained/bn5c_branch2b_mean
# ResNet101_pretrained/res3a_branch1_weights
# ResNet101_pretrained/bn3d_branch2c_offset
# ResNet101_pretrained/res5c_branch2b_weights
# ResNet101_pretrained/res4b4_branch2a_weights
# ResNet101_pretrained/res4b18_branch2a_weights
# ResNet101_pretrained/res4b11_branch2b_weights
# ResNet101_pretrained/bn3b_branch2a_mean
# ResNet101_pretrained/bn2b_branch2a_scale
# ResNet101_pretrained/bn2a_branch2a_variance
# ResNet101_pretrained/bn4b8_branch2a_variance
# ResNet101_pretrained/bn4b5_branch2a_scale
# ResNet101_pretrained/bn4b18_branch2c_scale
# ResNet101_pretrained/res4b10_branch2b_weights
# ResNet101_pretrained/bn4b11_branch2b_mean
# ResNet101_pretrained/bn4b12_branch2b_mean
# ResNet101_pretrained/bn4b3_branch2a_mean
# ResNet101_pretrained/bn4b17_branch2b_mean
# ResNet101_pretrained/bn4b21_branch2b_variance
# ResNet101_pretrained/res4b9_branch2c_weights
# ResNet101_pretrained/res5c_branch2a_weights
# ResNet101_pretrained/bn4b8_branch2b_variance
# ResNet101_pretrained/conv1_weights
# ResNet101_pretrained/bn4b15_branch2b_scale
# ResNet101_pretrained/res4b4_branch2c_weights
# ResNet101_pretrained/bn3d_branch2c_mean
# ResNet101_pretrained/res4b22_branch2c_weights
# ResNet101_pretrained/fc_0.w_0
# ResNet101_pretrained/bn4b5_branch2a_variance
# ResNet101_pretrained/bn4b16_branch2a_variance
# ResNet101_pretrained/bn4b17_branch2b_offset
# ResNet101_pretrained/bn2b_branch2a_variance
# ResNet101_pretrained/bn4b5_branch2b_mean
# ResNet101_pretrained/bn4b5_branch2c_offset
# ResNet101_pretrained/bn4b13_branch2c_mean
# ResNet101_pretrained/bn3b_branch2c_mean
# ResNet101_pretrained/res4b3_branch2c_weights
# ResNet101_pretrained/bn4b3_branch2a_scale
# ResNet101_pretrained/bn4b19_branch2a_variance
# ResNet101_pretrained/bn5b_branch2b_offset
# ResNet101_pretrained/bn4b21_branch2c_variance
# ResNet101_pretrained/res4b21_branch2a_weights
# ResNet101_pretrained/bn5a_branch2a_scale
# ResNet101_pretrained/bn4b7_branch2b_mean
# ResNet101_pretrained/bn2b_branch2b_offset
# ResNet101_pretrained/bn4b18_branch2c_variance
# ResNet101_pretrained/bn5c_branch2a_scale
# ResNet101_pretrained/bn3a_branch2a_scale
# ResNet101_pretrained/res4b20_branch2b_weights
# ResNet101_pretrained/bn4b9_branch2b_scale
# ResNet101_pretrained/res4b8_branch2a_weights
# ResNet101_pretrained/bn4b7_branch2c_offset
# ResNet101_pretrained/res3a_branch2b_weights
# ResNet101_pretrained/bn5a_branch2b_offset
# ResNet101_pretrained/bn4b11_branch2b_offset
# ResNet101_pretrained/bn4b9_branch2b_offset
# ResNet101_pretrained/res4b21_branch2b_weights
# ResNet101_pretrained/bn3a_branch2b_offset
# ResNet101_pretrained/bn4b13_branch2c_variance
# ResNet101_pretrained/bn2a_branch2b_mean
# ResNet101_pretrained/bn4b14_branch2c_mean
# ResNet101_pretrained/res4b19_branch2a_weights
# ResNet101_pretrained/res5b_branch2b_weights
# ResNet101_pretrained/res4b17_branch2b_weights
# ResNet101_pretrained/bn4a_branch1_scale
# ResNet101_pretrained/bn4b11_branch2b_scale
# ResNet101_pretrained/bn4b13_branch2a_variance
# ResNet101_pretrained/bn2a_branch2b_offset
# ResNet101_pretrained/bn4b19_branch2a_offset
# ResNet101_pretrained/bn4b7_branch2a_offset
# ResNet101_pretrained/bn4b11_branch2a_mean
# ResNet101_pretrained/bn5a_branch2b_variance
# ResNet101_pretrained/bn4b8_branch2a_mean
# ResNet101_pretrained/bn5b_branch2c_variance
# ResNet101_pretrained/bn4b19_branch2b_offset
# ResNet101_pretrained/bn4b5_branch2c_variance
# ResNet101_pretrained/res4b9_branch2a_weights
# ResNet101_pretrained/bn4b10_branch2a_offset
# ResNet101_pretrained/bn4b6_branch2b_scale
# ResNet101_pretrained/bn4b5_branch2b_variance
# ResNet101_pretrained/bn4b20_branch2c_scale
# ResNet101_pretrained/bn4b4_branch2c_scale
# ResNet101_pretrained/res5c_branch2c_weights
# ResNet101_pretrained/bn4b21_branch2a_offset
# ResNet101_pretrained/bn4b4_branch2a_offset
# ResNet101_pretrained/res4b14_branch2c_weights
# ResNet101_pretrained/res4b10_branch2a_weights
# ResNet101_pretrained/bn4b9_branch2b_variance
# ResNet101_pretrained/bn4a_branch1_mean
# ResNet101_pretrained/bn4b3_branch2c_mean
# ResNet101_pretrained/bn4b2_branch2b_mean
# ResNet101_pretrained/bn4b14_branch2a_scale
# ResNet101_pretrained/bn2a_branch1_variance
# ResNet101_pretrained/bn4b16_branch2b_scale
# ResNet101_pretrained/bn2c_branch2a_variance
# ResNet101_pretrained/bn4b20_branch2b_variance
# ResNet101_pretrained/bn4b10_branch2b_offset
# ResNet101_pretrained/bn2a_branch2c_variance
# ResNet101_pretrained/bn3c_branch2a_scale
# ResNet101_pretrained/bn4b1_branch2b_variance
# ResNet101_pretrained/bn4b18_branch2c_offset
# ResNet101_pretrained/bn5c_branch2b_scale
# ResNet101_pretrained/bn3a_branch2b_scale
# ResNet101_pretrained/bn4b20_branch2a_variance
# ResNet101_pretrained/res4b16_branch2c_weights
# ResNet101_pretrained/bn4b22_branch2b_offset
# ResNet101_pretrained/bn4b17_branch2a_scale
# ResNet101_pretrained/bn4a_branch2b_offset
# ResNet101_pretrained/bn4b7_branch2a_variance
# ResNet101_pretrained/bn4b10_branch2c_variance
# ResNet101_pretrained/bn3d_branch2b_offset
# ResNet101_pretrained/bn4b12_branch2b_variance
# ResNet101_pretrained/bn4b17_branch2c_offset
# ResNet101_pretrained/res4b10_branch2c_weights
# ResNet101_pretrained/bn4b19_branch2c_mean
# ResNet101_pretrained/bn4b16_branch2a_offset
# ResNet101_pretrained/res4b22_branch2b_weights
# ResNet101_pretrained/bn4b21_branch2c_offset
# ResNet101_pretrained/res5a_branch2b_weights
# ResNet101_pretrained/bn4b11_branch2a_offset
# ResNet101_pretrained/res4b4_branch2b_weights
# ResNet101_pretrained/bn3a_branch2c_mean
# ResNet101_pretrained/bn5b_branch2b_scale
# ResNet101_pretrained/bn4b15_branch2b_offset
# ResNet101_pretrained/bn4b13_branch2b_variance
# ResNet101_pretrained/bn4b2_branch2a_variance
# ResNet101_pretrained/bn4a_branch2a_variance
# ResNet101_pretrained/bn4b1_branch2a_variance
# ResNet101_pretrained/bn2b_branch2c_variance
# ResNet101_pretrained/bn4b10_branch2b_scale
# ResNet101_pretrained/bn4b9_branch2c_mean
# ResNet101_pretrained/bn4b9_branch2b_mean
# ResNet101_pretrained/bn4b4_branch2b_offset
# ResNet101_pretrained/bn4b17_branch2c_scale
# ResNet101_pretrained/bn2c_branch2c_offset
# ResNet101_pretrained/bn4b7_branch2b_scale
# ResNet101_pretrained/res4b16_branch2b_weights
# ResNet101_pretrained/res4b12_branch2b_weights
# ResNet101_pretrained/bn4b21_branch2c_scale
# ResNet101_pretrained/bn4b17_branch2b_variance
# ResNet101_pretrained/bn4b4_branch2c_variance
# ResNet101_pretrained/res2c_branch2c_weights
# ResNet101_pretrained/bn2c_branch2b_scale
# ResNet101_pretrained/bn3d_branch2a_offset
# ResNet101_pretrained/bn2a_branch1_scale
# ResNet101_pretrained/bn4b9_branch2a_variance
# ResNet101_pretrained/res4b12_branch2c_weights
# ResNet101_pretrained/res4a_branch2a_weights
# ResNet101_pretrained/bn4b5_branch2b_offset
# ResNet101_pretrained/bn4b10_branch2a_scale
# ResNet101_pretrained/bn4b17_branch2c_mean
# ResNet101_pretrained/bn5b_branch2a_mean
# ResNet101_pretrained/res4b14_branch2a_weights
# ResNet101_pretrained/bn4b13_branch2b_scale
# ResNet101_pretrained/bn4b10_branch2c_mean
# ResNet101_pretrained/bn4b13_branch2a_offset
# ResNet101_pretrained/bn4b3_branch2c_offset
# ResNet101_pretrained/bn2b_branch2c_scale
# ResNet101_pretrained/bn4b19_branch2b_mean
# ResNet101_pretrained/bn5a_branch1_offset
# ResNet101_pretrained/bn4b12_branch2c_scale
# ResNet101_pretrained/res3c_branch2b_weights
# ResNet101_pretrained/res4b16_branch2a_weights
# ResNet101_pretrained/bn2b_branch2c_mean
# ResNet101_pretrained/res4b22_branch2a_weights
# ResNet101_pretrained/bn4b3_branch2c_scale
# ResNet101_pretrained/bn5c_branch2a_mean
# ResNet101_pretrained/bn4b1_branch2a_scale
# ResNet101_pretrained/bn3a_branch1_scale
# ResNet101_pretrained/bn4b15_branch2c_variance
# ResNet101_pretrained/bn3c_branch2c_variance
# ResNet101_pretrained/bn4b21_branch2b_offset
# ResNet101_pretrained/bn5c_branch2a_variance
# ResNet101_pretrained/bn4b8_branch2c_variance
# ResNet101_pretrained/res4a_branch2b_weights
# ResNet101_pretrained/res4a_branch1_weights
# ResNet101_pretrained/bn3c_branch2a_offset
# ResNet101_pretrained/bn2c_branch2b_variance
# ResNet101_pretrained/bn2c_branch2a_offset
# ResNet101_pretrained/bn3c_branch2b_scale
# ResNet101_pretrained/bn4b19_branch2a_mean
# ResNet101_pretrained/bn4a_branch2c_offset
# ResNet101_pretrained/bn_conv1_mean
# ResNet101_pretrained/bn3c_branch2b_offset
# ResNet101_pretrained/bn3d_branch2a_mean
# ResNet101_pretrained/bn4b17_branch2c_variance
# ResNet101_pretrained/bn4b3_branch2b_scale
# ResNet101_pretrained/bn2b_branch2a_mean
# ResNet101_pretrained/bn4b16_branch2a_mean
# ResNet101_pretrained/bn4b9_branch2a_scale
# ResNet101_pretrained/bn3b_branch2b_offset
# ResNet101_pretrained/bn4b12_branch2a_variance
# ResNet101_pretrained/res3d_branch2a_weights
# ResNet101_pretrained/bn4b12_branch2a_scale
# ResNet101_pretrained/bn4b19_branch2b_scale
# ResNet101_pretrained/bn5a_branch1_scale
# ResNet101_pretrained/bn5b_branch2c_mean
# ResNet101_pretrained/bn3b_branch2b_scale
# ResNet101_pretrained/bn4b14_branch2a_mean
# ResNet101_pretrained/bn4b17_branch2a_mean
# ResNet101_pretrained/bn5c_branch2c_variance
# ResNet101_pretrained/res4b5_branch2c_weights
# ResNet101_pretrained/res4b8_branch2b_weights
# ResNet101_pretrained/bn4b10_branch2c_scale
# ResNet101_pretrained/bn4b7_branch2b_offset
# ResNet101_pretrained/bn4b6_branch2c_scale
# ResNet101_pretrained/bn4b20_branch2c_mean
# ResNet101_pretrained/bn4b2_branch2b_offset
# ResNet101_pretrained/res5a_branch1_weights
# ResNet101_pretrained/res3c_branch2a_weights
# ResNet101_pretrained/bn4b2_branch2c_mean
# ResNet101_pretrained/bn4b15_branch2a_variance
# ResNet101_pretrained/bn4b1_branch2a_offset
# ResNet101_pretrained/bn5b_branch2a_variance
# ResNet101_pretrained/res4b12_branch2a_weights
# ResNet101_pretrained/bn4b19_branch2c_offset
# ResNet101_pretrained/res4b6_branch2c_weights
# ResNet101_pretrained/bn4b12_branch2a_offset
# ResNet101_pretrained/bn2b_branch2b_scale
# ResNet101_pretrained/bn4b13_branch2b_offset
# ResNet101_pretrained/res2c_branch2b_weights
# ResNet101_pretrained/bn2a_branch2c_offset
# ResNet101_pretrained/bn4b2_branch2a_offset
# ResNet101_pretrained/res2b_branch2c_weights
# ResNet101_pretrained/bn3a_branch2a_offset
# ResNet101_pretrained/bn4b18_branch2b_scale
# ResNet101_pretrained/bn5a_branch2c_mean
# ResNet101_pretrained/bn4b4_branch2a_mean
# ResNet101_pretrained/bn4b6_branch2c_variance
# ResNet101_pretrained/bn4b1_branch2c_offset
# ResNet101_pretrained/bn4a_branch1_variance
# ResNet101_pretrained/bn4b6_branch2a_offset
# ResNet101_pretrained/res3a_branch2a_weights
# ResNet101_pretrained/bn4b7_branch2c_mean
# ResNet101_pretrained/bn4b5_branch2c_scale
# ResNet101_pretrained/bn2b_branch2c_offset
# ResNet101_pretrained/bn2c_branch2c_variance
# ResNet101_pretrained/bn2a_branch2a_offset
# ResNet101_pretrained/bn4b22_branch2a_mean
# ResNet101_pretrained/bn3a_branch1_variance
# ResNet101_pretrained/res2a_branch1_weights
# ResNet101_pretrained/bn4b13_branch2a_mean
# ResNet101_pretrained/bn4b21_branch2b_mean
# ResNet101_pretrained/bn4b3_branch2c_variance
# ResNet101_pretrained/res4b3_branch2a_weights
# ResNet101_pretrained/bn5a_branch2c_scale
# ResNet101_pretrained/res4b20_branch2c_weights
# ResNet101_pretrained/bn4b19_branch2c_variance
# ResNet101_pretrained/bn2a_branch2c_scale
# ResNet101_pretrained/bn4b19_branch2a_scale
# ResNet101_pretrained/res5b_branch2a_weights
# ResNet101_pretrained/bn4b1_branch2b_mean
# ResNet101_pretrained/bn5b_branch2a_scale
# ResNet101_pretrained/bn4b12_branch2b_offset
# ResNet101_pretrained/res4b13_branch2a_weights
# ResNet101_pretrained/bn5c_branch2c_offset
# ResNet101_pretrained/bn3c_branch2c_scale
# ResNet101_pretrained/bn4b19_branch2c_scale
# ResNet101_pretrained/bn4b13_branch2c_offset
# ResNet101_pretrained/bn5c_branch2c_mean
# ResNet101_pretrained/bn4b1_branch2c_scale
# ResNet101_pretrained/bn4b14_branch2c_scale
# ResNet101_pretrained/bn4b16_branch2c_offset
# ResNet101_pretrained/bn4b6_branch2a_scale
# ResNet101_pretrained/res4b17_branch2a_weights

# %% [markdown]
# # Step-1

# %%
import os
import shutil
import paddle as paddle
import paddle.fluid as fluid
from paddle.fluid.param_attr import ParamAttr
import reader
import numpy as np
import pandas as pd

# %%
##生成test.txt
#filepath='cat_12/cat_12_test'
#pathlist=os.listdir(filepath)
#print(pathlist)
#with open('cat_12/test_list.txt','w+') as f:
    #for file_name in pathlist:
        #f.write(file_name+'\n')

# %%
a=pd.read_table('cat_12/train_list.txt',header=None)
print(a[1].value_counts())
# Out:
# 11    180
# 9     180
# 7     180
# 5     180
# 3     180
# 1     180
# 10    180
# 8     180
# 6     180
# 4     180
# 2     180
# 0     180
# Name: 1, dtype: int64
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
##处理数据集，将原有训练集按二八比例分割
with open('cat_12/train_list.txt','r') as f:
    with open('cat_12/train_split_list.txt','w+') as train:
        lines=f.readlines()
    with open('cat_12/train_split_list.txt','w+') as train:
        for i in range(0,2160,180):
            for line in lines[i:i+135]:
                train.write(line)
    with open('cat_12/val_split_list.txt','w+') as val:
        for i in range(0,2160,180):
            for line in lines[i+135:i+180]:
                val.write(line)

# %%
train=pd.read_table('cat_12/train_split_list.txt',header=None)
print(train[1].value_counts())
val=pd.read_table('cat_12/val_split_list.txt',header=None)
print(val[1].value_counts())
# Out:
# 11    135
# 10    135
# 9     135
# 8     135
# 7     135
# 6     135
# 5     135
# 4     135
# 3     135
# 2     135
# 1     135
# 0     135
# Name: 1, dtype: int64
# 11    45
# 10    45
# 9     45
# 8     45
# 7     45
# 6     45
# 5     45
# 4     45
# 3     45
# 2     45
# 1     45
# 0     45
# Name: 1, dtype: int64
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
##获取猫数据
train_reader = paddle.batch(reader.train(), batch_size=32)
test_reader = paddle.batch(reader.val(), batch_size=32)

# %%
##定义残差网络
def resnet(input):
    def conv_bn_layer(input, num_filters, filter_size, stride=1, groups=1, act=None, name=None):
        conv = fluid.layers.conv2d(input=input,
                                   num_filters=num_filters,
                                   filter_size=filter_size,
                                   stride=stride,
                                   padding=(filter_size - 1) // 2,
                                   groups=groups,
                                   act=None,
                                   param_attr=ParamAttr(name=name + "_weights"),
                                   bias_attr=False,
                                   name=name + '.conv2d.output.1')
        if name == "conv1":
            bn_name = "bn_" + name
        else:
            bn_name = "bn" + name[3:]
        return fluid.layers.batch_norm(input=conv,
                                       act=act,
                                       name=bn_name + '.output.1',
                                       param_attr=ParamAttr(name=bn_name + '_scale'),
                                       bias_attr=ParamAttr(bn_name + '_offset'),
                                       moving_mean_name=bn_name + '_mean',
                                       moving_variance_name=bn_name + '_variance', )

    def shortcut(input, ch_out, stride, name):
        ch_in = input.shape[1]
        if ch_in != ch_out or stride != 1:
            return conv_bn_layer(input, ch_out, 1, stride, name=name)
        else:
            return input
            
    def bottleneck_block(input, num_filters, stride, name):
        conv0 = conv_bn_layer(input=input,
                              num_filters=num_filters,
                              filter_size=1,
                              act='relu',
                              name=name + "_branch2a")
        conv1 = conv_bn_layer(input=conv0,
                              num_filters=num_filters,
                              filter_size=3,
                              stride=stride,
                              act='relu',
                              name=name + "_branch2b")
        conv2 = conv_bn_layer(input=conv1,
                              num_filters=num_filters * 4,
                              filter_size=1,
                              act=None,
                              name=name + "_branch2c")

        short = shortcut(input, num_filters * 4, stride, name=name + "_branch1")

        return fluid.layers.elementwise_add(x=short, y=conv2, act='relu', name=name + ".add.output.5")

    depth = [3, 4, 23, 3]
    num_filters = [64, 128, 256, 512]

    conv = conv_bn_layer(input=input, num_filters=64, filter_size=7, stride=2, act='relu', name="conv1")
    conv = fluid.layers.pool2d(input=conv, pool_size=3, pool_stride=2, pool_padding=1, pool_type='max')

    for block in range(len(depth)):
        for i in range(depth[block]):
            if block == 2:
                if i == 0:
                    conv_name="res"+str(block+2)+"a"
                else:
                    conv_name="res"+str(block+2)+"b"+str(i)
            else:
                    conv_name="res"+str(block+2)+chr(97+i)
            conv = bottleneck_block(input=conv,
                                    num_filters=num_filters[block],
                                    stride=2 if i == 0 and block != 0 else 1,
                                    name=conv_name)

    pool = fluid.layers.pool2d(input=conv, pool_size=7, pool_type='avg', global_pooling=True)
    return pool

# %%
##定义输入层
image=fluid.layers.data(name='image',shape=[3,224,224],dtype='float32')
label=fluid.layers.data(name='label',shape=[1],dtype='int64')

# %%
##停止梯度下降
pool=resnet(image)
pool.stop_gradient=True

##创建主程序
base_model_program=fluid.default_main_program().clone()
model=fluid.layers.fc(input=pool,size=12,act='softmax')

# %%
##定义损失函数和准确率函数
cost=fluid.layers.cross_entropy(input=model,label=label)
avg_cost=fluid.layers.mean(cost)
acc=fluid.layers.accuracy(input=model,label=label)

##定义优化方法
optimizer=fluid.optimizer.AdamOptimizer(learning_rate=1e-4)
opts=optimizer.minimize(avg_cost)

##定义训练场所
use_gpu=True
place=fluid.CUDAPlace(0) if use_gpu else fluid.CPUPlace()
exe=fluid.Executor(place)

##进行参数初始化
exe.run(fluid.default_startup_program())
# Out:
# []

# %%
##预训练模型路径
src_pretrain_model_path='work/pretrained/ResNet101_pretrained'

##判断模型文件是否存在
def if_exit(var):
    path=os.path.join(src_pretrain_model_path,var.name)
    exist=os.path.exists(path)
    return exist

##加载模型文件，且只加载存在模型的模型文件
fluid.io.load_vars(executor=exe,dirname=src_pretrain_model_path,predicate=if_exit,main_program=base_model_program)

# %%
##优化内存
optimized = fluid.transpiler.memory_optimize(input_program=fluid.default_main_program(), print_log=False)

##定义数据维度
feeder=fluid.DataFeeder(place=place,feed_list=[image,label])

for pass_id in range(15):
    for batch_id,data in enumerate(train_reader()):
        train_cost,train_acc=exe.run(program = fluid.default_main_program(),feed=feeder.feed(data),fetch_list=[avg_cost,acc])
        if batch_id%50==0:
            print('Pass:%d, Batch:%d, Cost:%0.5f, Accuracy:%0.5f' %
                  (pass_id, batch_id, train_cost[0], train_acc[0]))
# Out:
# memory_optimize is deprecated. Use CompiledProgram and Executor
# Pass:0, Batch:0, Cost:2.84497, Accuracy:0.03125
# Pass:0, Batch:50, Cost:2.52071, Accuracy:0.20000
# Pass:1, Batch:0, Cost:2.25010, Accuracy:0.31250
# Pass:1, Batch:50, Cost:2.06762, Accuracy:0.25000
# Pass:2, Batch:0, Cost:2.12661, Accuracy:0.34375
# Pass:2, Batch:50, Cost:1.84726, Accuracy:0.45000
# Pass:3, Batch:0, Cost:1.58517, Accuracy:0.68750
# Pass:3, Batch:50, Cost:1.63683, Accuracy:0.60000
# Pass:4, Batch:0, Cost:1.45348, Accuracy:0.65625
# Pass:4, Batch:50, Cost:1.45984, Accuracy:0.50000
# Pass:5, Batch:0, Cost:1.35630, Accuracy:0.65625
# Pass:5, Batch:50, Cost:1.40717, Accuracy:0.65000
# Pass:6, Batch:0, Cost:1.31520, Accuracy:0.65625
# Pass:6, Batch:50, Cost:1.29443, Accuracy:0.65000
# Pass:7, Batch:0, Cost:1.17565, Accuracy:0.75000
# Pass:7, Batch:50, Cost:1.18256, Accuracy:0.65000
# Pass:8, Batch:0, Cost:1.02226, Accuracy:0.75000
# Pass:8, Batch:50, Cost:1.24088, Accuracy:0.75000
# Pass:9, Batch:0, Cost:1.36751, Accuracy:0.56250
# Pass:9, Batch:50, Cost:1.18662, Accuracy:0.70000
# Pass:10, Batch:0, Cost:1.23318, Accuracy:0.62500
# Pass:10, Batch:50, Cost:0.96939, Accuracy:0.85000
# Pass:11, Batch:0, Cost:0.96475, Accuracy:0.68750
# Pass:11, Batch:50, Cost:0.98189, Accuracy:0.65000
# Pass:12, Batch:0, Cost:0.83133, Accuracy:0.78125
# Pass:12, Batch:50, Cost:0.68434, Accuracy:0.80000
# Pass:13, Batch:0, Cost:0.97741, Accuracy:0.75000
# Pass:13, Batch:50, Cost:0.80245, Accuracy:0.85000
# Pass:14, Batch:0, Cost:1.00433, Accuracy:0.71875
# Pass:14, Batch:50, Cost:0.84641, Accuracy:0.80000

# %%
save_pretrain_model_path='models/step-1_model/'

##删除旧的模型文件
shutil.rmtree(save_pretrain_model_path,ignore_errors=True)
##创建保存模型文件记录
os.makedirs(save_pretrain_model_path)
##保存参数模型
fluid.io.save_params(executor=exe,dirname=save_pretrain_model_path)

# %% [markdown]
# # Step-2

# %%
import os
import shutil
import paddle as paddle
import paddle.dataset.flowers as flowers
import paddle.fluid as fluid
from paddle.fluid.param_attr import ParamAttr
import reader

# %%
##获取数据
train_reader = paddle.batch(reader.train(), batch_size=16)
test_reader = paddle.batch(reader.val(), batch_size=16)

# %%
##定义resnet，加上fc
def resnet(input,class_dim):
    def conv_bn_layer(input, num_filters, filter_size, stride=1, groups=1, act=None, name=None):
        conv = fluid.layers.conv2d(input=input,
                                   num_filters=num_filters,
                                   filter_size=filter_size,
                                   stride=stride,
                                   padding=(filter_size - 1) // 2,
                                   groups=groups,
                                   act=None,
                                   param_attr=ParamAttr(name=name + "_weights"),
                                   bias_attr=False,
                                   name=name + '.conv2d.output.1')
        if name == "conv1":
            bn_name = "bn_" + name
        else:
            bn_name = "bn" + name[3:]
        return fluid.layers.batch_norm(input=conv,
                                       act=act,
                                       name=bn_name + '.output.1',
                                       param_attr=ParamAttr(name=bn_name + '_scale'),
                                       bias_attr=ParamAttr(bn_name + '_offset'),
                                       moving_mean_name=bn_name + '_mean',
                                       moving_variance_name=bn_name + '_variance', )

    def shortcut(input, ch_out, stride, name):
        ch_in = input.shape[1]
        if ch_in != ch_out or stride != 1:
            return conv_bn_layer(input, ch_out, 1, stride, name=name)
        else:
            return input
            
    def bottleneck_block(input, num_filters, stride, name):
        conv0 = conv_bn_layer(input=input,
                              num_filters=num_filters,
                              filter_size=1,
                              act='relu',
                              name=name + "_branch2a")
        conv1 = conv_bn_layer(input=conv0,
                              num_filters=num_filters,
                              filter_size=3,
                              stride=stride,
                              act='relu',
                              name=name + "_branch2b")
        conv2 = conv_bn_layer(input=conv1,
                              num_filters=num_filters * 4,
                              filter_size=1,
                              act=None,
                              name=name + "_branch2c")

        short = shortcut(input, num_filters * 4, stride, name=name + "_branch1")

        return fluid.layers.elementwise_add(x=short, y=conv2, act='relu', name=name + ".add.output.5")

    depth = [3, 4, 23, 3]
    num_filters = [64, 128, 256, 512]

    conv = conv_bn_layer(input=input, num_filters=64, filter_size=7, stride=2, act='relu', name="conv1")
    conv = fluid.layers.pool2d(input=conv, pool_size=3, pool_stride=2, pool_padding=1, pool_type='max')

    for block in range(len(depth)):
        for i in range(depth[block]):
            if block == 2:
                if i == 0:
                    conv_name="res"+str(block+2)+"a"
                else:
                    conv_name="res"+str(block+2)+"b"+str(i)
            else:
                    conv_name="res"+str(block+2)+chr(97+i)
            conv = bottleneck_block(input=conv,
                                    num_filters=num_filters[block],
                                    stride=2 if i == 0 and block != 0 else 1,
                                    name=conv_name)

    pool = fluid.layers.pool2d(input=conv, pool_size=7, pool_type='avg', global_pooling=True)
    output=fluid.layers.fc(input=pool,size=class_dim,act='softmax')
    return output

# %%
##定义输入层
image = fluid.layers.data(name='image', shape=[3, 224, 224], dtype='float32')
label = fluid.layers.data(name='label', shape=[1], dtype='int64')

##获取分类器
model = resnet(image,12)

# %%
##获取损失函数和准确率函数
cost = fluid.layers.cross_entropy(input=model, label=label)
avg_cost = fluid.layers.mean(cost)
acc = fluid.layers.accuracy(input=model, label=label)

# %%
##获取训练和测试程序
test_program = fluid.default_main_program().clone(for_test=True)

# %%
##定义优化方法
optimizer=fluid.optimizer.AdamOptimizer(learning_rate=1e-5)
opts=optimizer.minimize(avg_cost)

# %%
##定义一个使用GPU的执行器
use_gpu=True
place=fluid.CUDAPlace(0) if use_gpu else fluid.CPUPlace()
exe=fluid.Executor(place)

##进行参数初始化
exe.run(fluid.default_startup_program())
# Out:
# []

# %%
##经过step-1处理后的的预训练模型
pretrained_model_path = 'models/step-1_model/'

##加载经过处理的模型
fluid.io.load_params(executor=exe, dirname=pretrained_model_path)

# %%
##定义数据维度
feeder=fluid.DataFeeder(place=place,feed_list=[image,label])
for pass_id in range(10):
    ##训练
    for batch_id,data in enumerate(train_reader()):
        train_cost,train_acc=exe.run(program=fluid.default_main_program(),feed=feeder.feed(data),fetch_list=[avg_cost,acc])
        if batch_id%10==0:
            print('Pass:%d, Batch:%d, Cost:%0.5f, Accuracy:%0.5f' %
                  (pass_id, batch_id, train_cost[0], train_acc[0]))
    ##测试
    test_accs=[]
    test_costs=[]
    for batch_id,data in enumerate(test_reader()):
        test_cost,test_acc=exe.run(program=test_program,feed=feeder.feed(data), fetch_list=[avg_cost,acc])
        test_accs.append(test_acc[0])
        test_costs.append(test_cost[0])
    test_cost = (sum(test_costs) / len(test_costs))
    test_acc = (sum(test_accs) / len(test_accs))
    print('Test:%d, Cost:%0.5f, Accuracy:%0.5f' % (pass_id, test_cost, test_acc))
# Out:
# Pass:0, Batch:0, Cost:0.78239, Accuracy:0.87500
# Pass:0, Batch:10, Cost:0.88325, Accuracy:0.68750
# Pass:0, Batch:20, Cost:0.80515, Accuracy:0.68750
# Pass:0, Batch:30, Cost:0.70883, Accuracy:0.81250
# Pass:0, Batch:40, Cost:0.79519, Accuracy:0.75000
# Pass:0, Batch:50, Cost:0.57010, Accuracy:0.93750
# Pass:0, Batch:60, Cost:0.57044, Accuracy:0.93750
# Pass:0, Batch:70, Cost:0.62551, Accuracy:0.87500
# Pass:0, Batch:80, Cost:0.54036, Accuracy:0.87500
# Pass:0, Batch:90, Cost:0.70725, Accuracy:0.81250
# Pass:0, Batch:100, Cost:0.80666, Accuracy:0.75000
# Test:0, Cost:0.33298, Accuracy:0.91176
# Pass:1, Batch:0, Cost:0.64048, Accuracy:0.75000
# Pass:1, Batch:10, Cost:0.44968, Accuracy:0.93750
# Pass:1, Batch:20, Cost:0.36878, Accuracy:0.93750
# Pass:1, Batch:30, Cost:0.69417, Accuracy:0.75000
# Pass:1, Batch:40, Cost:0.40586, Accuracy:0.93750
# Pass:1, Batch:50, Cost:0.50115, Accuracy:0.75000
# Pass:1, Batch:60, Cost:0.45978, Accuracy:0.87500
# Pass:1, Batch:70, Cost:0.39089, Accuracy:0.87500
# Pass:1, Batch:80, Cost:0.41843, Accuracy:0.87500
# Pass:1, Batch:90, Cost:0.62945, Accuracy:0.75000
# Pass:1, Batch:100, Cost:0.54257, Accuracy:0.75000
# Test:1, Cost:0.25402, Accuracy:0.92279
# Pass:2, Batch:0, Cost:0.55526, Accuracy:0.75000
# Pass:2, Batch:10, Cost:0.47011, Accuracy:0.87500
# Pass:2, Batch:20, Cost:0.32310, Accuracy:0.93750
# Pass:2, Batch:30, Cost:0.27928, Accuracy:0.93750
# Pass:2, Batch:40, Cost:0.42568, Accuracy:0.93750
# Pass:2, Batch:50, Cost:0.26000, Accuracy:1.00000
# Pass:2, Batch:60, Cost:0.41043, Accuracy:0.81250
# Pass:2, Batch:70, Cost:0.33747, Accuracy:0.87500
# Pass:2, Batch:80, Cost:0.56950, Accuracy:0.81250
# Pass:2, Batch:90, Cost:0.29326, Accuracy:0.87500
# Pass:2, Batch:100, Cost:0.80813, Accuracy:0.56250
# Test:2, Cost:0.24514, Accuracy:0.91912
# Pass:3, Batch:0, Cost:0.54930, Accuracy:0.81250
# Pass:3, Batch:10, Cost:0.41280, Accuracy:0.87500
# Pass:3, Batch:20, Cost:0.24185, Accuracy:0.93750
# Pass:3, Batch:30, Cost:0.43259, Accuracy:0.87500
# Pass:3, Batch:40, Cost:0.20602, Accuracy:1.00000
# Pass:3, Batch:50, Cost:0.45759, Accuracy:0.81250
# Pass:3, Batch:60, Cost:0.29760, Accuracy:0.87500
# Pass:3, Batch:70, Cost:0.46487, Accuracy:0.81250
# Pass:3, Batch:80, Cost:0.21574, Accuracy:0.93750
# Pass:3, Batch:90, Cost:0.37897, Accuracy:0.87500
# Pass:3, Batch:100, Cost:0.54832, Accuracy:0.87500
# Test:3, Cost:0.25332, Accuracy:0.92279
# Pass:4, Batch:0, Cost:0.30600, Accuracy:0.87500
# Pass:4, Batch:10, Cost:0.11481, Accuracy:1.00000
# Pass:4, Batch:20, Cost:0.50202, Accuracy:0.81250
# Pass:4, Batch:30, Cost:0.16333, Accuracy:1.00000
# Pass:4, Batch:40, Cost:0.29065, Accuracy:0.93750
# Pass:4, Batch:50, Cost:0.71113, Accuracy:0.81250
# Pass:4, Batch:60, Cost:0.74252, Accuracy:0.68750
# Pass:4, Batch:70, Cost:0.26945, Accuracy:1.00000
# Pass:4, Batch:80, Cost:0.70906, Accuracy:0.75000
# Pass:4, Batch:90, Cost:0.38839, Accuracy:0.87500
# Pass:4, Batch:100, Cost:0.20651, Accuracy:1.00000
# Test:4, Cost:0.20390, Accuracy:0.92647
# Pass:5, Batch:0, Cost:0.37190, Accuracy:0.87500
# Pass:5, Batch:10, Cost:0.56685, Accuracy:0.75000
# Pass:5, Batch:20, Cost:0.23527, Accuracy:1.00000
# Pass:5, Batch:30, Cost:0.16010, Accuracy:1.00000
# Pass:5, Batch:40, Cost:0.19070, Accuracy:0.93750
# Pass:5, Batch:50, Cost:0.08373, Accuracy:1.00000
# Pass:5, Batch:60, Cost:0.48535, Accuracy:0.81250
# Pass:5, Batch:70, Cost:0.55381, Accuracy:0.75000
# Pass:5, Batch:80, Cost:0.17482, Accuracy:0.93750
# Pass:5, Batch:90, Cost:0.38455, Accuracy:0.81250
# Pass:5, Batch:100, Cost:0.26196, Accuracy:0.93750
# Test:5, Cost:0.18711, Accuracy:0.93934
# Pass:6, Batch:0, Cost:0.30767, Accuracy:0.93750
# Pass:6, Batch:10, Cost:0.50996, Accuracy:0.81250
# Pass:6, Batch:20, Cost:0.07358, Accuracy:1.00000
# Pass:6, Batch:30, Cost:0.30954, Accuracy:0.81250
# Pass:6, Batch:40, Cost:0.37712, Accuracy:0.81250
# Pass:6, Batch:50, Cost:0.32150, Accuracy:0.93750
# Pass:6, Batch:60, Cost:0.19292, Accuracy:1.00000
# Pass:6, Batch:70, Cost:0.05310, Accuracy:1.00000
# Pass:6, Batch:80, Cost:0.42979, Accuracy:0.81250
# Pass:6, Batch:90, Cost:0.11181, Accuracy:0.93750
# Pass:6, Batch:100, Cost:0.25751, Accuracy:0.93750
# Test:6, Cost:0.17837, Accuracy:0.93934
# Pass:7, Batch:0, Cost:0.38271, Accuracy:0.75000
# Pass:7, Batch:10, Cost:0.19832, Accuracy:0.93750
# Pass:7, Batch:20, Cost:0.23401, Accuracy:0.93750
# Pass:7, Batch:30, Cost:0.14495, Accuracy:0.93750
# Pass:7, Batch:40, Cost:0.26425, Accuracy:0.81250
# Pass:7, Batch:50, Cost:0.25993, Accuracy:0.93750
# Pass:7, Batch:60, Cost:0.12763, Accuracy:0.93750
# Pass:7, Batch:70, Cost:0.64658, Accuracy:0.87500
# Pass:7, Batch:80, Cost:0.13542, Accuracy:0.93750
# Pass:7, Batch:90, Cost:0.28911, Accuracy:0.87500
# Pass:7, Batch:100, Cost:0.36345, Accuracy:0.87500
# Test:7, Cost:0.18711, Accuracy:0.93199
# Pass:8, Batch:0, Cost:0.21174, Accuracy:0.87500
# Pass:8, Batch:10, Cost:0.08551, Accuracy:1.00000
# Pass:8, Batch:20, Cost:0.16540, Accuracy:0.93750
# Pass:8, Batch:30, Cost:0.31375, Accuracy:0.93750
# Pass:8, Batch:40, Cost:0.33846, Accuracy:0.87500
# Pass:8, Batch:50, Cost:0.18797, Accuracy:0.93750
# Pass:8, Batch:60, Cost:0.09722, Accuracy:1.00000
# Pass:8, Batch:70, Cost:0.54152, Accuracy:0.68750
# Pass:8, Batch:80, Cost:0.07723, Accuracy:1.00000
# Pass:8, Batch:90, Cost:0.19463, Accuracy:0.93750
# Pass:8, Batch:100, Cost:0.13637, Accuracy:0.93750
# Test:8, Cost:0.19440, Accuracy:0.93750
# Pass:9, Batch:0, Cost:0.30098, Accuracy:0.93750
# Pass:9, Batch:10, Cost:0.20268, Accuracy:1.00000
# Pass:9, Batch:20, Cost:0.46000, Accuracy:0.87500
# Pass:9, Batch:30, Cost:0.19310, Accuracy:0.93750
# Pass:9, Batch:40, Cost:0.46715, Accuracy:0.93750
# Pass:9, Batch:50, Cost:0.22768, Accuracy:0.93750
# Pass:9, Batch:60, Cost:0.28804, Accuracy:0.81250
# Pass:9, Batch:70, Cost:0.16123, Accuracy:1.00000
# Pass:9, Batch:80, Cost:0.51409, Accuracy:0.87500
# Pass:9, Batch:90, Cost:0.11259, Accuracy:1.00000
# Pass:9, Batch:100, Cost:0.20922, Accuracy:0.87500
# Test:9, Cost:0.18871, Accuracy:0.93015

# %%
##保存预测模型
save_path = 'models/step_2_model/'

##删除旧的模型文件
shutil.rmtree(save_path, ignore_errors=True)
##创建保持模型文件目录
os.makedirs(save_path)
##保存预测模型
fluid.io.save_inference_model(save_path, feeded_var_names=[image.name], target_vars=[model], executor=exe)
# Out:
# ['save_infer_model/scale_0']

# %%
SAVE_DIRNAME = './models/step_2_model'  # 保存好的 inference model 的路径

#########################################################################


"""
运行generate_CSV_file_with_infer.py
脚本文件generate_CSV_file_with_infer.py实现生成CSV文件的功能
脚本文件将读取训练好的模型（model）和测试集数据（test）
并将模型对测试集数据的预测结果保存为CSV文件
"""

# coding:utf-8
from __future__ import print_function
import os
import json

import paddle
import paddle.fluid as fluid
import numpy as np
from PIL import Image
import sys


# 根据竞赛规则更改 TopK 的值。本次竞赛只看 top 1 的值
TOP_K = 1

SAVE_DIRNAME = './models/step_2_model'  # 保存好的 inference model 的路径

DATA_DIM = 224

use_cuda = True
place = fluid.CUDAPlace(0) if use_cuda else fluid.CPUPlace()
exe = fluid.Executor(place)

# 下面行代码根据自己保存时的写法匹配
[inference_program, feed_target_names, fetch_targets] = fluid.io.load_inference_model( SAVE_DIRNAME, exe,
                # model_filename='model',
                # params_filename='params'
                # model_filename = 'fc_0.w_0',
                # params_filename = 'params'
                )


def real_infer_one_img(im):
    infer_result = exe.run(
        inference_program,
        feed={feed_target_names[0]: im},
        fetch_list=fetch_targets)

    # print(infer_result)
    # 打印预测结果
    mini_batch_result = np.argsort(infer_result)  # 找出可能性最大的列标，升序排列
    # print(mini_batch_result.shape)
    mini_batch_result = mini_batch_result[0][:, -TOP_K:]  # 把这些列标拿出来
    # print('预测结果：%s' % mini_batch_result)
    # 打印真实结果
    # label = np.array(test_y)  # 转化为 label
    # print('真实结果：%s' % label)
    mini_batch_result = mini_batch_result.flatten() #拉平了，只吐出一个 array
    mini_batch_result = mini_batch_result[::-1] #逆序
    return mini_batch_result


def resize_short(img, target_size):
    percent = float(target_size) / min(img.size[0], img.size[1])
    resized_width = int(round(img.size[0] * percent))
    resized_height = int(round(img.size[1] * percent))
    img = img.resize((resized_width, resized_height), Image.LANCZOS)
    return img


def crop_image(img, target_size, center):
    width, height = img.size
    size = target_size
    if center == True:
        w_start = (width - size) / 2
        h_start = (height - size) / 2
    else:
        w_start = np.random.randint(0, width - size + 1)
        h_start = np.random.randint(0, height - size + 1)
    w_end = w_start + size
    h_end = h_start + size
    img = img.crop((w_start, h_start, w_end, h_end))
    return img

img_mean = np.array([0.485, 0.456, 0.406]).reshape((3, 1, 1))
img_std = np.array([0.229, 0.224, 0.225]).reshape((3, 1, 1))

def process_image(img_path):
    img = Image.open(img_path)
    img = resize_short(img, target_size=256)
    img = crop_image(img, target_size=DATA_DIM, center=True)

    if img.mode != 'RGB':
        img = img.convert('RGB')

    img = np.array(img).astype(np.float32).transpose((2, 0, 1)) / 255
    img -= img_mean
    img /= img_std

    img = np.expand_dims(img, axis=0)
    return img


def convert_list(my_list):
    my_list = list(my_list)
    my_list = map(lambda x:str(x), my_list)
    # print('_'.join(my_list))
    return '_'.join(my_list)


def infer(file_path):
    im = process_image(file_path)
    result = real_infer_one_img(im)
    result = convert_list(result)
    return result




def createCSVFile(cat_12_test_path):
    lines = []

    # 获取所有的文件名
    img_paths = os.listdir(cat_12_test_path)
    for file_name in img_paths:
        file_name = file_name
        file_abs_path = os.path.join(cat_12_test_path, file_name)
        result_classes = infer(file_abs_path)

        file_predict_classes = result_classes

        line = '%s,%s\n'%(file_name, file_predict_classes)
        lines.append(line)

    with open('csv_file_path.csv', 'w') as f:
        f.writelines(lines)


abs_path = r'./cat_12/cat_12_test' # cat_12_test 文件夹的真实路径
createCSVFile(abs_path)
